# %% [markdown]
# 1) features that will affect the buying behaviour are:
# City,	StateProvinceName,	CountryRegionName,	PostalCode,	PhoneNumber,	BirthDate,	Education,	Occupation,	Gender,	MaritalStatus,	HomeOwnerFlag,	NumberCarsOwned,	NumberChildrenAtHome,	TotalChildren,	YearlyIncome

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/AWCustomers.csv')
df.drop(['CustomerID','Title','FirstName','MiddleName','LastName','Suffix','AddressLine1','AddressLine2','LastUpdated'],axis=1,inplace=True)
df.head()
# Out:
#           City    StateProvinceName CountryRegionName PostalCode  \
# 0   Wollongong      New South Wales         Australia       2500
# 1      Shawnee     British Columbia            Canada    V9B 2C3
# 2  West Covina           California     United States      91791
# 3    Liverpool              England    United Kingdom     L4 4HB
# 4        Werne  Nordrhein-Westfalen           Germany      59368
#
#            PhoneNumber   BirthDate        Education      Occupation Gender  \
# 0  1 (11) 500 555-0115  1987-11-13        Bachelors        Clerical      M
# 1         787-555-0136  1972-07-21  Partial College        Clerical      M
# 2         120-555-0111  1985-11-09        Bachelors        Clerical      F
# 3  1 (11) 500 555-0167  1977-10-18  Partial College  Skilled Manual      M
# 4  1 (11) 500 555-0113  1975-02-05  Partial College  Skilled Manual      M
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# ...

# %% [markdown]
# City,StateProvinceName,CountryRegionName,PostalCode,PhoneNumber,BirthDate,Education,Occupation,Gender,MaritalStatus,HomeOwnerFlag,NumberCarsOwned,	NumberChildrenAtHome,TotalChildren,YearlyIncome
#
# **continuous attributes:** yearly income
#
# **discrete attributes:**  postal code, phone number, birth date, number of cars owned, number of children at home, total children
#
# **nominal attributes:** City,StateProvinceName,CountryRegionName,Occupation,Gender,MaritalStatus,HomeOwnerFlag
#
# **ordinal attributes:** yearly income
#
# **interval:** postal code, birth date, yearly income
#
# **range:** number of children at home, total children,Number of cars owned

# %%
df.dropna()
# Out:
#                  City    StateProvinceName CountryRegionName PostalCode  \
# 0          Wollongong      New South Wales         Australia       2500
# 1             Shawnee     British Columbia            Canada    V9B 2C3
# 2         West Covina           California     United States      91791
# 3           Liverpool              England    United Kingdom     L4 4HB
# 4               Werne  Nordrhein-Westfalen           Germany      59368
# ...               ...                  ...               ...        ...
# 11782         Bobigny    Seine Saint Denis            France      93000
# 11783           Colma           California     United States      94014
# 11784         Shawnee     British Columbia            Canada    V8Z 4N5
# 11785  Roissy en Brie       Seine et Marne            France      77680
# 11786       Milwaukie               Oregon     United States      97222
#
#                PhoneNumber   BirthDate        Education      Occupation  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['YearlyIncome']=scaler.fit_transform(df['YearlyIncome'].values.reshape(-1,1)).flatten()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-85a67db03005> in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
# ----> 3 df['YearlyIncome']=scaler.fit_transform(df['YearlyIncome'].values.reshape(-1,1)).flatten()
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     414         # Reset internal state before fitting
#     415         self._reset()
# --> 416         return self.partial_fit(X, y)
# ...

# %%
bins=np.linspace(min(df['YearlyIncome']),max(df['YearlyIncome']),4)

group_names=['poor','average','rich']

df['YearlyIncome']=pd.cut(df['YearlyIncome'],bins,group_names,include_lowest=True)

# %%
onehotencoder = OneHotEncoder()
onehotencoder.fit_transform(df)
# Out:
# <11788x13201 sparse matrix of type '<class 'numpy.float64'>'
# 	with 176820 stored elements in Compressed Sparse Row format>

# %%
df.corr()
# Out:
#                       HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# HomeOwnerFlag              1.000000         0.202841              0.372930
# NumberCarsOwned            0.202841         1.000000              0.016433
# NumberChildrenAtHome       0.372930         0.016433              1.000000
# TotalChildren              0.578898         0.018703              0.609808
#
#                       TotalChildren
# HomeOwnerFlag              0.578898
# NumberCarsOwned            0.018703
# NumberChildrenAtHome       0.609808
# TotalChildren              1.000000
